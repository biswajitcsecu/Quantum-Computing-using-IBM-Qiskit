# %%
import cudaq

# %%
@cudaq.kernel
def kernel():
    qubit = cudaq.qubit()
    h(qubit)
    x(qubit)
    y(qubit)
    z(qubit)
    t(qubit)
    s(qubit)
    mz(qubit)
result = cudaq.sample(kernel)
print(result)
# Out:
# { 0:509 1:491 }
